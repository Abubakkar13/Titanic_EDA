# %% [markdown]
# # <center>EXPLORATORY DATA ANALYSIS ON TITANIC SURVIVAL</center>
#
# > <code>NAME : <b>ABUBAKKAR SIDDIQUE</b></code><br>
# > <code>QUALIFICATION : <b>Bachelor of Engineering</b></code><br>
# > <code>UNIVERSITY : <b>VTU</b></code><br>
# > <code>LOCATION : <b>Bangalore, KA, INDIA</b></code><br>
#
# This Project is to perform the analysis on the Titanic Survival using the Provided dataset file of it.
# Here we use various libraries of Python for visualization of Data.
# The Dataset which is Used in Project is from <a href=''>Shape AI</a>
#
# The Libraries I used in Project are:
# * Matplotlib <a href='https://matplotlib.org/'> Explore here </a>
# * Seaborn <a href='https://seaborn.pydata.org/'> Explore here </a>
# * Numpy <a href='https://numpy.org/'> Explore here </a>
# * Pandas <a href='https://pandas.pydata.org/'> Explore here </a>
#
#
# To install all required libraries, run the following Command:
#
# `pip install numpy pandas matplotlib seaborn  plotly --upgrade`
#
#
# **Know About Data visualization:**
# >  *The Data visualization is the graphic representation of data. It involves producing images that communicate relationships among the represented data to viewers. Visualizing data is an essential part of data analysis and machine learning. In this tutorial, we'll use Python libraries Matplotlib and Seaborn to learn and apply some popular data visualization techniques.*
#
# **Their Following Tasks are Implemented in the Project:**
#
# > *DATA PREPROCESSING <br>
# > DATA VISUALIZATION via EDA*

# %% [markdown]
# # <center>Let's get Dive into Project</center>

# %%
#Importing all the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <center>Data Preparation and Cleaning</center>
#
# Here various modes of displaying dataset which is in CSV format.
# First step is to load the data using pandas read_csv function. The data is stored in mutidimensional table called as dataframe.

# %%
data = 'train.csv' #locate the CSV dataset in variable data 

titanic_df = pd.read_csv(data) #read the data using pandas and store it in titanic_df variable
titanic_df #display the data (completely )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **This Cell is to Explain the details of all Columns :**
#
# * PassengerId : Unique ID for each Passenger
# * Survived : Survial of passenger
# * Pclass : Ticket class
# * Name : Passenger Name
# * Sex : Gender
# * Age : Age of Passenger in years
# * SibSp : Number of Siblings/Spouses aboard the Titanic
# * Parch : Number of parents/children aboard the Titanic
# * Ticket : Ticket number
# * Fare : Passenger Fare
# * Cabin : Cabin number
# * Embarked : Port from where passenger embarked (C, Q, S)

# %%
#To know the type of data, lets check!
type(titanic_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Now will be getting the list of all appiccable methods that can be applied on our dataframe
dir(titanic_df)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'T',
#  'Ticket',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
# ...

# %%
#To show top 15 rows
titanic_df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                              Heikkinen, Miss. Laina  female  26.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
#To show 15 rows from bottom
titanic_df.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name     Sex        Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.000000      0
# 877                           Petroff, Mr. Nedelio    male  19.000000      0
# 878                             Laleff, Mr. Kristo    male  29.699118      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.000000      0
# ...

# %%
# Now to describe the dataframe
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Lets check the number of rows and coloumns
titanic_df.shape
# Out:
# (891, 12)

# %%
#next will check for empty cells  in our dataset
titanic_df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#After confirming with emptyness, will fill those with the mean of that coloumn
titanic_df.fillna(titanic_df.mean(), inplace=True)
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Now will drop/separate a column with more than 50% of empty cells.

# %%
z = titanic_df.isnull().sum()
drop_col = z[z > (50/100 * titanic_df.shape[0])]
drop_col
# Out:
# Cabin    687
# dtype: int64

# %% [markdown]
# Therefore, after the execution of above code snippet we come to know that <b>Cabin</b> column is the one with more that 50% of empty cells

# %%
drop_col.index
# Out:
# Index(['Cabin'], dtype='object')

# %%
titanic_df.drop(drop_col.index, axis=1, inplace=True)
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
#Now we cannot calculate mean for the String values,
#hence we go for the one whose frequency of occurance is maximum to fill the empty cell
titanic_df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
titanic_df['Embarked'].fillna('S', inplace=True)
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# And Finally all the empty cells have been filled with respective known value

# %% [markdown]
# # <center>Data Visualization with EDA</center>

# %% [markdown]
# ### Few randomly created visualization on Titanic survival Dataset
# Now, to use Matplotlib, Seaborn library to visualize the Dataset.

# %%
plt.figure(figsize=(10,6))
sns.countplot('Survived',data=titanic_df)
plt.title('Plot to show the Survived or Not')
plt.show()

# %%
#Plot to visualize number of Males and Females

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Male','Female']
index = [577,314]
ax.bar(gender,index)
plt.xlabel("Gender")
plt.ylabel("No of people onboarding ship")
plt.show()

# %%
alive = len(titanic_df[titanic_df['Survived'] == 1])
dead = len(titanic_df[titanic_df['Survived'] == 0])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
status = ['Survived','Dead']
ind = [alive,dead]
ax.bar(status,ind)
plt.xlabel("Status")
plt.show()

# %%
titanic_df.groupby('Sex')[['Survived']].mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
plt.figure(1)
titanic_df.loc[titanic_df['Survived'] == 1, 'Pclass'].value_counts().sort_index().plot.bar()
plt.title('Bar graph of people accrding to ticket class in which people survived')


plt.figure(2)
titanic_df.loc[titanic_df['Survived'] == 0, 'Pclass'].value_counts().sort_index().plot.bar()
plt.title('Bar graph of people accrding to ticket class in which people couldn\'t survive')
# Out:
# Text(0.5, 1.0, "Bar graph of people accrding to ticket class in which people couldn't survive")

# %%
# Now using seaborn to plot the count of passengers in each class

fg = sns.factorplot('Pclass', data=titanic_df, kind='count', aspect=1.5)
fg.set_xlabels('Class')

# %%
# Number of men and women in each of the passenger class
titanic_df.groupby(['Sex', 'Pclass'])['Sex'].count()
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# Name: Sex, dtype: int64

# %%
# Again use saeborn to group by Sex and class
g = sns.factorplot('Pclass', data=titanic_df, hue='Sex', kind='count', aspect=1.75)
g.set_xlabels('Class')

# %%
# Drop missing values for the records in which age passenger is missing
age = titanic_df['Age'].dropna()

age_dist = sns.distplot(age)
age_dist.set_title("Distribution of Passengers' Ages")
# Out:
# Text(0.5, 1.0, "Distribution of Passengers' Ages")

# %%
titanic_df['Age'].hist(bins=30)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
#Scatterplot Method
plt.figure(figsize=(15,4))
sns.scatterplot(titanic_df.Fare[0:350], # X-axis taken in range from 0 to 350
                titanic_df.Pclass[0:450],  # Y-axis taken in range from 0 to 450
                hue=titanic_df.PassengerId,  # Dot color
                s=90)
plt.title("Scatterplot view for Fare upon Ticket clas", fontdict={'fontsize':24})

#Xlabel and Ylabel are in titanic_df
# Out:
# Text(0.5, 1.0, 'Scatterplot view for Fare upon Ticket clas')

# %%
# Heatmap view of all column names

plt.figure(figsize=(15,12), dpi= 50)
#sold = sns.load_dataset(.corr())
sns.heatmap(titanic_df.corr('pearson'),annot=True, cmap = 'jet')
